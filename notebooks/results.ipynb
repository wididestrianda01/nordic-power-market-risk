# %% [markdown]
# # P16 — results notebook
#
# This notebook renders the headline figures from the pipeline outputs. It calls the same
# `render_all` function that the `nordic-risk figures` command uses, so the figures are
# reproducible from the command line too. Run the pipeline stages first; each figure
# renders only when its source output exists.

# %%
from nordic_power_risk.config import get_config
from nordic_power_risk.report.figures import render_all

written = render_all(get_config())
written

# %%
from pathlib import Path

from IPython.display import Image, display

for path in sorted(Path("docs/figures").glob("*.png")):
    display(Image(filename=str(path)))
